# %% [markdown]
# ### Konstantina Andronikou

# %% [markdown]
# ## This Notebook implements Predicate Ellipsis

# %%
from allennlp_models.pretrained import load_predictor

# %%
import checklist
import logging 
import csv
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect

# %%
from checklist.pred_wrapper import PredictorWrapper

# %%
#removing warnings
logging.getLogger('allennlp.common.params').disabled = True 
logging.getLogger('allennlp.nn.initializers').disabled = True 
logging.getLogger('allennlp.modules.token_embedders.embedding').disabled = True 
logging.getLogger('urllib3.connectionpool').disabled = True 
logging.getLogger('allennlp.common.plugins').disabled = True 
logging.getLogger('allennlp.common.model_card').disabled = True 
logging.getLogger('allennlp.models.archival').disabled = True 
logging.getLogger('allennlp.data.vocabulary').disabled = True 
logging.getLogger('cached_path').disabled = True
srl_predictor = load_predictor('structured-prediction-srl')
output = srl_predictor.predict("John saw three dogs and Mary two.")
output
# Out:
# {'verbs': [{'verb': 'saw',
#    'description': '[ARG0: John] [V: saw] [ARG1: three dogs and Mary two] .',
#    'tags': ['B-ARG0',
#     'B-V',
#     'B-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'I-ARG1',
#     'O']}],
#  'words': ['John', 'saw', 'three', 'dogs', 'and', 'Mary', 'two', '.']}

# %%
def predict_srl(data):
    
    pred = []
    for d in data:
        pred.append(srl_predictor.predict(d))
    return pred

predict_and_conf = PredictorWrapper.wrap_predict(predict_srl)

# %%
d = ["John saw three dogs and Mary two"]
pred = predict_and_conf(d)
pred
# Out:
# ([{'verbs': [{'verb': 'saw',
#      'description': '[ARG0: John] [V: saw] [ARG1: three dogs and Mary two]',
#      'tags': ['B-ARG0',
#       'B-V',
#       'B-ARG1',
#       'I-ARG1',
#       'I-ARG1',
#       'I-ARG1',
#       'I-ARG1']}],
#    'words': ['John', 'saw', 'three', 'dogs', 'and', 'Mary', 'two']}],
#  array([1.]))

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    
    return pred['verbs'][0]['description']

# %%
def get_arg(pred, arg_target='ARG0'):
    predicate_arguments = pred['verbs'][0]
    #print(predicate_arguments)
    words = pred['words']
    tags = predicate_arguments['tags']
    
    arg_list = []
    for t, w in zip(tags, words):
        arg = t
        if '-' in t:
            arg = t.split('-')[1]
        if arg == arg_target:
            arg_list.append(w)
    arg_set = set(arg_list)
    return arg_set

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    results = []
    predicate_structure = pred['verbs'][0]['description']
        
    return predicate_structure

# %%
def found_arg0_people(x, pred, conf, label=None, meta=None):
    
    # people should be recognized as arg1

    people = set([meta['first_name1']])
    arg_0 = get_arg(pred, arg_target='ARG0')

    if arg_0 == people:
        pass_ = True
    else:
        pass_ = False
    return pass_


expect_arg0 = Expect.single(found_arg0_people)

# %%
editor = Editor()

# create examples
t = editor.template('{first_name} saw three dogs and {first_name1} two.', meta=True, nsamples=1000, remove_duplicates = True)

#print(type(t))

for k, v in t.items():
    print(k, v)
# Out:
# meta [{'first_name': 'Lisa', 'first_name1': 'Heather'}, {'first_name': 'Judy', 'first_name1': 'Andrew'}, {'first_name': 'John', 'first_name1': 'Ray'}, {'first_name': 'Frederick', 'first_name1': 'Alexander'}, {'first_name': 'Al', 'first_name1': 'Marie'}, {'first_name': 'Kelly', 'first_name1': 'Kathleen'}, {'first_name': 'Greg', 'first_name1': 'Betty'}, {'first_name': 'Melissa', 'first_name1': 'Jack'}, {'first_name': 'Frances', 'first_name1': 'Matthew'}, {'first_name': 'Marie', 'first_name1': 'Florence'}, {'first_name': 'Patricia', 'first_name1': 'Stephen'}, {'first_name': 'Alexander', 'first_name1': 'Victoria'}, {'first_name': 'Susan', 'first_name1': 'Heather'}, {'first_name': 'Martha', 'first_name1': 'Angela'}, {'first_name': 'Katie', 'first_name1': 'Jane'}, {'first_name': 'Evelyn', 'first_name1': 'Barbara'}, {'first_name': 'William', 'first_name1': 'Judy'}, {'first_name': 'Steve', 'first_name1': 'Matthew'}, {'first_name': 'Kenneth', 'first_name1': 'Annie'}, {'first_name': 'Harriet', 'first_name1': 'Scott'}, {'first_name': 'Kathy', 'first_name1': 'Jonathan'}, {'first_name': 'Bill', 'first_name1': 'Jennifer'}, {'first_name': 'Al', 'first_name1': 'Charlie'}, {'first_name': 'Walter', 'first_name1': 'Rebecca'}, {'first_name': 'Margaret', 'first_name1': 'Jay'}, {'first_name': 'Sandra', 'first_name1': 'Carolyn'}, {'first_name': 'Betty', 'first_name1': 'Howard'}, {'first_name': 'Simon', 'first_name1': 'Roger'}, {'first_name': 'Laura', 'first_name1': 'Judith'}, {'first_name': 'Steve', 'first_name1': 'Hugh'}, {'first_name': 'Sharon', 'first_name1': 'Simon'}, {'first_name': 'Robert', 'first_name1': 'Martin'}, {'first_name': 'Andrew', 'first_name1': 'Anthony'}, {'first_name': 'Greg', 'first_name1': 'Richard'}, {'first_name': 'Alfred', 'first_name1': 'Edward'}, {'first_name': 'Gary', 'first_name1': 'Benjamin'}, {'first_name': 'Marie', 'first_name1': 'Ray'}, {'first_name': 'Kenneth', 'first_name1': 'Ruth'}, {'first_name': 'Donald', 'first_name1': 'Al'}, {'first_name': 'Charlotte', 'first_name1': 'Cynthia'}, {'first_name': 'Greg', 'first_name1': 'Dick'}, {'first_name': 'Frederick', 'first_name1': 'Laura'}, {'first_name': 'Louis', 'first_name1': 'Carl'}, {'first_name': 'Kate', 'first_name1': 'Joseph'}, {'first_name': 'Scott', 'first_name1': 'Angela'}, {'first_name': 'Stephanie', 'first_name1': 'Kathy'}, {'first_name': 'Al', 'first_name1': 'Kelly'}, {'first_name': 'Susan', 'first_name1': 'Andrea'}, {'first_name': 'Andrea', 'first_name1': 'Matt'}, {'first_name': 'Lucy', 'first_name1': 'Walter'}, {'first_name': 'Scott', 'first_name1': 'Annie'}, {'first_name': 'Robin', 'first_name1': 'Dave'}, {'first_name': 'Tom', 'first_name1': 'Fiona'}, {'first_name': 'Sara', 'first_name1': 'Stephanie'}, {'first_name': 'Sue', 'first_name1': 'Kim'}, {'first_name': 'David', 'first_name1': 'Jim'}, {'first_name': 'Samuel', 'first_name1': 'Caroline'}, {'first_name': 'Angela', 'first_name1': 'Mike'}, {'first_name': 'Henry', 'first_name1': 'Johnny'}, {'first_name': 'Evelyn', 'first_name1': 'Charlotte'}, {'first_name': 'Ken', 'first_name1': 'Robin'}, {'first_name': 'Barbara', 'first_name1': 'Robert'}, {'first_name': 'Robin', 'first_name1': 'Lucy'}, {'first_name': 'Fred', 'first_name1': 'Paul'}, {'first_name': 'Annie', 'first_name1': 'Alexandra'}, {'first_name': 'Alexandra', 'first_name1': 'Andrea'}, {'first_name': 'Judith', 'first_name1': 'Sophie'}, {'first_name': 'Kathryn', 'first_name1': 'Jason'}, {'first_name': 'Robert', 'first_name1': 'Don'}, {'first_name': 'Sandra', 'first_name1': 'Jean'}, {'first_name': 'Elaine', 'first_name1': 'Walter'}, {'first_name': 'Diane', 'first_name1': 'Julie'}, {'first_name': 'Richard', 'first_name1': 'Virginia'}, {'first_name': 'Sue', 'first_name1': 'Sophie'}, {'first_name': 'Lawrence', 'first_name1': 'Matthew'}, {'first_name': 'Philip', 'first_name1': 'Anthony'}, {'first_name': 'Fred', 'first_name1': 'Alex'}, {'first_name': 'Tom', 'first_name1': 'Jason'}, {'first_name': 'Amy', 'first_name1': 'Judith'}, {'first_name': 'Steven', 'first_ ...
# data ['Lisa saw three dogs and Heather two.', 'Judy saw three dogs and Andrew two.', 'John saw three dogs and Ray two.', 'Frederick saw three dogs and Alexander two.', 'Al saw three dogs and Marie two.', 'Kelly saw three dogs and Kathleen two.', 'Greg saw three dogs and Betty two.', 'Melissa saw three dogs and Jack two.', 'Frances saw three dogs and Matthew two.', 'Marie saw three dogs and Florence two.', 'Patricia saw three dogs and Stephen two.', 'Alexander saw three dogs and Victoria two.', 'Susan saw three dogs and Heather two.', 'Martha saw three dogs and Angela two.', 'Katie saw three dogs and Jane two.', 'Evelyn saw three dogs and Barbara two.', 'William saw three dogs and Judy two.', 'Steve saw three dogs and Matthew two.', 'Kenneth saw three dogs and Annie two.', 'Harriet saw three dogs and Scott two.', 'Kathy saw three dogs and Jonathan two.', 'Bill saw three dogs and Jennifer two.', 'Al saw three dogs and Charlie two.', 'Walter saw three dogs and Rebecca two.', 'Margaret saw three dogs and Jay two.', 'Sandra saw three dogs and Carolyn two.', 'Betty saw three dogs and Howard two.', 'Simon saw three dogs and Roger two.', 'Laura saw three dogs and Judith two.', 'Steve saw three dogs and Hugh two.', 'Sharon saw three dogs and Simon two.', 'Robert saw three dogs and Martin two.', 'Andrew saw three dogs and Anthony two.', 'Greg saw three dogs and Richard two.', 'Alfred saw three dogs and Edward two.', 'Gary saw three dogs and Benjamin two.', 'Marie saw three dogs and Ray two.', 'Kenneth saw three dogs and Ruth two.', 'Donald saw three dogs and Al two.', 'Charlotte saw three dogs and Cynthia two.', 'Greg saw three dogs and Dick two.', 'Frederick saw three dogs and Laura two.', 'Louis saw three dogs and Carl two.', 'Kate saw three dogs and Joseph two.', 'Scott saw three dogs and Angela two.', 'Stephanie saw three dogs and Kathy two.', 'Al saw three dogs and Kelly two.', 'Susan saw three dogs and Andrea two.', 'Andrea saw three dogs and Matt two.', 'Lucy saw three dogs and Walter two.', 'Scott saw three dogs and Annie two.', 'Robin saw three dogs and Dave two.', 'Tom saw three dogs and Fiona two.', 'Sara saw three dogs and Stephanie two.', 'Sue saw three dogs and Kim two.', 'David saw three dogs and Jim two.', 'Samuel saw three dogs and Caroline two.', 'Angela saw three dogs and Mike two.', 'Henry saw three dogs and Johnny two.', 'Evelyn saw three dogs and Charlotte two.', 'Ken saw three dogs and Robin two.', 'Barbara saw three dogs and Robert two.', 'Robin saw three dogs and Lucy two.', 'Fred saw three dogs and Paul two.', 'Annie saw three dogs and Alexandra two.', 'Alexandra saw three dogs and Andrea two.', 'Judith saw three dogs and Sophie two.', 'Kathryn saw three dogs and Jason two.', 'Robert saw three dogs and Don two.', 'Sandra saw three dogs and Jean two.', 'Elaine saw three dogs and Walter two.', 'Diane saw three dogs and Julie two.', 'Richard saw three dogs and Virginia two.', 'Sue saw three dogs and Sophie two.', 'Lawrence saw three dogs and Matthew two.', 'Philip saw three dogs and Anthony two.', 'Fred saw three dogs and Alex two.', 'Tom saw three dogs and Jason two.', 'Amy saw three dogs and Judith two.', 'Steven saw three dogs and Kelly two.', 'Sue saw three dogs and Jonathan two.', 'Andrea saw three dogs and Jay two.', 'Emily saw three dogs and Leslie two.', 'Matt saw three dogs and Melissa two.', 'Ellen saw three dogs and Jill two.', 'Amy saw three dogs and Greg two.', 'Roy saw three dogs and Dave two.', 'Carl saw three dogs and Dave two.', 'Emily saw three dogs and Alexandra two.', 'Jack saw three dogs and Roger two.', 'Dave saw three dogs and Alexandra two.', 'Rebecca saw three dogs and Grace two.', 'Claire saw three dogs and Leslie two.', 'Roger saw three dogs and Mary two.', 'Michael saw three dogs and Martin two.', 'Rose saw three dogs and Julia two.', 'Martha saw three dogs and Frances two.', 'Don saw three dogs and Fiona two.', 'Alan saw three dogs and Gary two.', 'Judith saw three dogs and Laura two.' ...

# %%
with open('Dataset_BiLSTM/Predicate_Ellipsis.txt', 'w') as f:
    print(t.data, file = f)

# %%
# initialize a rest object
test = MFT(**t, name = 'detect_arg0_name_default_position', expect=expect_arg0)
output = test.run(predict_and_conf)
test.summary(format_example_fn=format_srl)
i = test.results['preds']
expect_for_i = test.results['expect_results']
with open ('Output_BiLSTM/Predicate_Ellipsis.csv','w') as f:
    writer = csv.writer(f)
    for result, exp in zip(i, expect_for_i):
        
        case = result['words']
        exp = exp
        writer.writerow([case, exp])
        print(case,exp)
# Out:
# Predicting 994 examples
# Test cases:      994
# Fails (rate):    994 (100.0%)
#
# Example fails:
# [ARG0: Jennifer] [V: saw] [ARG1: three dogs and Dan two] .
# ----
# [ARG0: Julia] [V: saw] [ARG1: three dogs and Amy two] .
# ----
# [ARG0: Caroline] [V: saw] [ARG1: three dogs and Ed two] .
# ----
# ['Lisa', 'saw', 'three', 'dogs', 'and', 'Heather', 'two', '.'] [False]
# ['Judy', 'saw', 'three', 'dogs', 'and', 'Andrew', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Frederick', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Al', 'saw', 'three', 'dogs', 'and', 'Marie', 'two', '.'] [False]
# ['Kelly', 'saw', 'three', 'dogs', 'and', 'Kathleen', 'two', '.'] [False]
# ['Greg', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Frances', 'saw', 'three', 'dogs', 'and', 'Matthew', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Florence', 'two', '.'] [False]
# ['Patricia', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Victoria', 'two', '.'] [False]
# ['Susan', 'saw', 'three', 'dogs', 'and', 'Heather', 'two', '.'] [False]
# ['Martha', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Judy', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Matthew', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Harriet', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Kathy', 'saw', 'three', 'dogs', 'and', 'Jonathan', 'two', '.'] [False]
# ['Bill', 'saw', 'three', 'dogs', 'and', 'Jennifer', 'two', '.'] [False]
# ['Al', 'saw', 'three', 'dogs', 'and', 'Charlie', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Margaret', 'saw', 'three', 'dogs', 'and', 'Jay', 'two', '.'] [False]
# ['Sandra', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Betty', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Simon', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Laura', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Hugh', 'two', '.'] [False]
# ['Sharon', 'saw', 'three', 'dogs', 'and', 'Simon', 'two', '.'] [False]
# ['Robert', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Anthony', 'two', '.'] [False]
# ['Greg', 'saw', 'three', 'dogs', 'and', 'Richard', 'two', '.'] [False]
# ['Alfred', 'saw', 'three', 'dogs', 'and', 'Edward', 'two', '.'] [False]
# ['Gary', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Ruth', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Al', 'two', '.'] [False]
# ['Charlotte', 'saw', 'three', 'dogs', 'and', 'Cynthia', 'two', '.'] [False]
# ['Greg', 'saw', 'three', 'dogs', 'and', 'Dick', 'two', '.'] [False]
# ['Frederick', 'saw', 'three', 'dogs', 'and', 'Laura', 'two', '.'] [False]
# ['Louis', 'saw', 'three', 'dogs', 'and', 'Carl', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Joseph', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Stephanie', 'saw', 'three', 'dogs', 'and', 'Kathy', 'two', '.'] [False]
# ['Al', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Susan', 'saw', 'three', 'dogs', 'and', 'Andrea', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Matt', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Dave', 'two', '.'] [False]
# ['Tom', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Sara', 'saw', 'three', 'dogs', 'and', 'Stephanie', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['David', 'saw', 'three', 'dogs', 'and', 'Jim', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Caroline', 'two', '.'] [False]
# ['Angela', 'saw', 'three', 'dogs', 'and', 'Mike', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Lucy', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Paul', 'two', '.'] [False]
# ['Annie', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Andrea', 'two', '.'] [False]
# ['Judith', 'saw', 'three', 'dogs', 'and', 'Sophie', 'two', '.'] [False]
# ['Kathryn', 'saw', 'three', 'dogs', 'and', 'Jason', 'two', '.'] [False]
# ['Robert', 'saw', 'three', 'dogs', 'and', 'Don', 'two', '.'] [False]
# ['Sandra', 'saw', 'three', 'dogs', 'and', 'Jean', 'two', '.'] [False]
# ['Elaine', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Julie', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Sophie', 'two', '.'] [False]
# ['Lawrence', 'saw', 'three', 'dogs', 'and', 'Matthew', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Anthony', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Tom', 'saw', 'three', 'dogs', 'and', 'Jason', 'two', '.'] [False]
# ['Amy', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Jonathan', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Jay', 'two', '.'] [False]
# ['Emily', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Matt', 'saw', 'three', 'dogs', 'and', 'Melissa', 'two', '.'] [False]
# ['Ellen', 'saw', 'three', 'dogs', 'and', 'Jill', 'two', '.'] [False]
# ['Amy', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Dave', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Dave', 'two', '.'] [False]
# ['Emily', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Jack', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Dave', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Rebecca', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Roger', 'saw', 'three', 'dogs', 'and', 'Mary', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Rose', 'saw', 'three', 'dogs', 'and', 'Julia', 'two', '.'] [False]
# ['Martha', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Don', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Alan', 'saw', 'three', 'dogs', 'and', 'Gary', 'two', '.'] [False]
# ['Judith', 'saw', 'three', 'dogs', 'and', 'Laura', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Ann', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Bruce', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Mary', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Sue', 'two', '.'] [False]
# ['Ralph', 'saw', 'three', 'dogs', 'and', 'Melissa', 'two', '.'] [False]
# ['Kathryn', 'saw', 'three', 'dogs', 'and', 'Alfred', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Larry', 'saw', 'three', 'dogs', 'and', 'Paul', 'two', '.'] [False]
# ['Jimmy', 'saw', 'three', 'dogs', 'and', 'Richard', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Ian', 'two', '.'] [False]
# ['Tim', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Thomas', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Louis', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Albert', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Nick', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Lynn', 'saw', 'three', 'dogs', 'and', 'Michelle', 'two', '.'] [False]
# ['Jack', 'saw', 'three', 'dogs', 'and', 'Kathryn', 'two', '.'] [False]
# ['Betty', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Bill', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Don', 'saw', 'three', 'dogs', 'and', 'Kenneth', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Marilyn', 'two', '.'] [False]
# ['Edwin', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Tom', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Matthew', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Linda', 'two', '.'] [False]
# ['Jonathan', 'saw', 'three', 'dogs', 'and', 'Hugh', 'two', '.'] [False]
# ['Julia', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Fred', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Emma', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['Emily', 'saw', 'three', 'dogs', 'and', 'Edith', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Diana', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Lawrence', 'two', '.'] [False]
# ['Harold', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Suzanne', 'two', '.'] [False]
# ['Simon', 'saw', 'three', 'dogs', 'and', 'Kevin', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Ron', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Mike', 'two', '.'] [False]
# ['Betty', 'saw', 'three', 'dogs', 'and', 'Evelyn', 'two', '.'] [False]
# ['Fiona', 'saw', 'three', 'dogs', 'and', 'Ellen', 'two', '.'] [False]
# ['Jennifer', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Betty', 'saw', 'three', 'dogs', 'and', 'Joan', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Kenneth', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Michael', 'two', '.'] [False]
# ['Mike', 'saw', 'three', 'dogs', 'and', 'Henry', 'two', '.'] [False]
# ['Stephanie', 'saw', 'three', 'dogs', 'and', 'Mary', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Kathleen', 'two', '.'] [False]
# ['Janet', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Jason', 'saw', 'three', 'dogs', 'and', 'Frederick', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['Grace', 'saw', 'three', 'dogs', 'and', 'Jill', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Brian', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Sandra', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Daniel', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Rachel', 'saw', 'three', 'dogs', 'and', 'Diane', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Lucy', 'two', '.'] [False]
# ['Elaine', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Ralph', 'saw', 'three', 'dogs', 'and', 'Christopher', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Sophie', 'two', '.'] [False]
# ['Alan', 'saw', 'three', 'dogs', 'and', 'Keith', 'two', '.'] [False]
# ['Jim', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Colin', 'two', '.'] [False]
# ['Angela', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Kathy', 'saw', 'three', 'dogs', 'and', 'Mike', 'two', '.'] [False]
# ['Amy', 'saw', 'three', 'dogs', 'and', 'Jerry', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Joan', 'two', '.'] [False]
# ['Albert', 'saw', 'three', 'dogs', 'and', 'Peter', 'two', '.'] [False]
# ['Amanda', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Jean', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Joan', 'saw', 'three', 'dogs', 'and', 'Michael', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Gary', 'two', '.'] [False]
# ['Leslie', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Arthur', 'two', '.'] [False]
# ['Karen', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Alfred', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Anthony', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Carl', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Edwin', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Frank', 'two', '.'] [False]
# ['Suzanne', 'saw', 'three', 'dogs', 'and', 'Emma', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Victoria', 'two', '.'] [False]
# ['Joseph', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Donald', 'two', '.'] [False]
# ['Sophie', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Emma', 'saw', 'three', 'dogs', 'and', 'Anne', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Sam', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Al', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Annie', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Emma', 'saw', 'three', 'dogs', 'and', 'Peter', 'two', '.'] [False]
# ['Hugh', 'saw', 'three', 'dogs', 'and', 'Cynthia', 'two', '.'] [False]
# ['Bill', 'saw', 'three', 'dogs', 'and', 'Maria', 'two', '.'] [False]
# ['James', 'saw', 'three', 'dogs', 'and', 'Elaine', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Linda', 'two', '.'] [False]
# ['Daniel', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Lauren', 'saw', 'three', 'dogs', 'and', 'Gary', 'two', '.'] [False]
# ['Ben', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Ed', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Ed', 'two', '.'] [False]
# ['Anne', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Frederick', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Sally', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Bruce', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Suzanne', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Amanda', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Sophie', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Harriet', 'saw', 'three', 'dogs', 'and', 'Patricia', 'two', '.'] [False]
# ['James', 'saw', 'three', 'dogs', 'and', 'Mark', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Diana', 'two', '.'] [False]
# ['Simon', 'saw', 'three', 'dogs', 'and', 'Daniel', 'two', '.'] [False]
# ['Bob', 'saw', 'three', 'dogs', 'and', 'Karen', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Dave', 'two', '.'] [False]
# ['Anna', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Nicole', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Marie', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Larry', 'saw', 'three', 'dogs', 'and', 'Roy', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Wendy', 'two', '.'] [False]
# ['Annie', 'saw', 'three', 'dogs', 'and', 'Kathy', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Anna', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Kathleen', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Bob', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Kelly', 'saw', 'three', 'dogs', 'and', 'Elizabeth', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Emily', 'saw', 'three', 'dogs', 'and', 'Diane', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Marie', 'two', '.'] [False]
# ['Jerry', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Suzanne', 'saw', 'three', 'dogs', 'and', 'Rose', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Lauren', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Angela', 'saw', 'three', 'dogs', 'and', 'Carl', 'two', '.'] [False]
# ['Thomas', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Margaret', 'two', '.'] [False]
# ['Jerry', 'saw', 'three', 'dogs', 'and', 'Julie', 'two', '.'] [False]
# ['Thomas', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Bill', 'saw', 'three', 'dogs', 'and', 'Kate', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Sophie', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Steve', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Jessica', 'two', '.'] [False]
# ['Ralph', 'saw', 'three', 'dogs', 'and', 'Jason', 'two', '.'] [False]
# ['Sandra', 'saw', 'three', 'dogs', 'and', 'Marie', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Tony', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Lawrence', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Joan', 'two', '.'] [False]
# ['Caroline', 'saw', 'three', 'dogs', 'and', 'Ed', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Charles', 'two', '.'] [False]
# ['Caroline', 'saw', 'three', 'dogs', 'and', 'Michael', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'George', 'two', '.'] [False]
# ['Dorothy', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Lauren', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Peter', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Patrick', 'two', '.'] [False]
# ['Louise', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Angela', 'saw', 'three', 'dogs', 'and', 'Ed', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Amanda', 'saw', 'three', 'dogs', 'and', 'Anna', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Patrick', 'two', '.'] [False]
# ['Carol', 'saw', 'three', 'dogs', 'and', 'Ron', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Harry', 'two', '.'] [False]
# ['Ron', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Katherine', 'two', '.'] [False]
# ['Alfred', 'saw', 'three', 'dogs', 'and', 'Marilyn', 'two', '.'] [False]
# ['Adam', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Ian', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Martin', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Kathy', 'saw', 'three', 'dogs', 'and', 'Emma', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Carolyn', 'saw', 'three', 'dogs', 'and', 'Arthur', 'two', '.'] [False]
# ['Sharon', 'saw', 'three', 'dogs', 'and', 'Susan', 'two', '.'] [False]
# ['Julia', 'saw', 'three', 'dogs', 'and', 'Rose', 'two', '.'] [False]
# ['Ben', 'saw', 'three', 'dogs', 'and', 'Frederick', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Henry', 'two', '.'] [False]
# ['Suzanne', 'saw', 'three', 'dogs', 'and', 'Lynn', 'two', '.'] [False]
# ['Don', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Julie', 'saw', 'three', 'dogs', 'and', 'Ian', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Hugh', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Martin', 'two', '.'] [False]
# ['Kathleen', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Harriet', 'saw', 'three', 'dogs', 'and', 'Jean', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Charles', 'two', '.'] [False]
# ['Anthony', 'saw', 'three', 'dogs', 'and', 'Margaret', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Anthony', 'saw', 'three', 'dogs', 'and', 'John', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Francis', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Benjamin', 'saw', 'three', 'dogs', 'and', 'David', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Bill', 'saw', 'three', 'dogs', 'and', 'Louis', 'two', '.'] [False]
# ['Ruth', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'Dorothy', 'two', '.'] [False]
# ['Dave', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Paul', 'two', '.'] [False]
# ['Elaine', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Johnny', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Mike', 'saw', 'three', 'dogs', 'and', 'Gary', 'two', '.'] [False]
# ['Anna', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Susan', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Maria', 'two', '.'] [False]
# ['Caroline', 'saw', 'three', 'dogs', 'and', 'Albert', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Andrew', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Alice', 'two', '.'] [False]
# ['David', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Donna', 'saw', 'three', 'dogs', 'and', 'Steven', 'two', '.'] [False]
# ['Rebecca', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Lawrence', 'saw', 'three', 'dogs', 'and', 'Patricia', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Harold', 'two', '.'] [False]
# ['Alfred', 'saw', 'three', 'dogs', 'and', 'Kate', 'two', '.'] [False]
# ['Charles', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Kim', 'saw', 'three', 'dogs', 'and', 'Joseph', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Sam', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Roy', 'two', '.'] [False]
# ['Larry', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Nancy', 'saw', 'three', 'dogs', 'and', 'Suzanne', 'two', '.'] [False]
# ['Mike', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Michelle', 'saw', 'three', 'dogs', 'and', 'Janet', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Julia', 'two', '.'] [False]
# ['Jimmy', 'saw', 'three', 'dogs', 'and', 'Tom', 'two', '.'] [False]
# ['Julie', 'saw', 'three', 'dogs', 'and', 'Billy', 'two', '.'] [False]
# ['Lisa', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Jennifer', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Julia', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Ben', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Jay', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Thomas', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Howard', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Christopher', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Ray', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Thomas', 'saw', 'three', 'dogs', 'and', 'Melissa', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Matthew', 'saw', 'three', 'dogs', 'and', 'Frederick', 'two', '.'] [False]
# ['Jennifer', 'saw', 'three', 'dogs', 'and', 'Sue', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Don', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Lawrence', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Hugh', 'saw', 'three', 'dogs', 'and', 'Philip', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Chris', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Louis', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Carol', 'two', '.'] [False]
# ['Karen', 'saw', 'three', 'dogs', 'and', 'Lynn', 'two', '.'] [False]
# ['Ellen', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Adam', 'two', '.'] [False]
# ['Ellen', 'saw', 'three', 'dogs', 'and', 'Alfred', 'two', '.'] [False]
# ['Matthew', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Andrew', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Ben', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'David', 'two', '.'] [False]
# ['Louis', 'saw', 'three', 'dogs', 'and', 'Anthony', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'Laura', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Tom', 'saw', 'three', 'dogs', 'and', 'Lynn', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Paul', 'saw', 'three', 'dogs', 'and', 'Anna', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Bob', 'saw', 'three', 'dogs', 'and', 'Emma', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Martha', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Rebecca', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Keith', 'saw', 'three', 'dogs', 'and', 'Stephanie', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Martha', 'saw', 'three', 'dogs', 'and', 'Sandra', 'two', '.'] [False]
# ['Kelly', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Maria', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Ian', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'Ian', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Steve', 'two', '.'] [False]
# ['Ian', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Carl', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Jill', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Rebecca', 'saw', 'three', 'dogs', 'and', 'Sue', 'two', '.'] [False]
# ['Caroline', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Carolyn', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Jim', 'two', '.'] [False]
# ['Carol', 'saw', 'three', 'dogs', 'and', 'Diana', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Henry', 'two', '.'] [False]
# ['Karen', 'saw', 'three', 'dogs', 'and', 'Thomas', 'two', '.'] [False]
# ['William', 'saw', 'three', 'dogs', 'and', 'Edward', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Billy', 'saw', 'three', 'dogs', 'and', 'Katherine', 'two', '.'] [False]
# ['Charles', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Philip', 'two', '.'] [False]
# ['Elizabeth', 'saw', 'three', 'dogs', 'and', 'Simon', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Joan', 'two', '.'] [False]
# ['Harold', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'Edwin', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Rose', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Emma', 'two', '.'] [False]
# ['Stephen', 'saw', 'three', 'dogs', 'and', 'Louis', 'two', '.'] [False]
# ['Greg', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['David', 'saw', 'three', 'dogs', 'and', 'Jennifer', 'two', '.'] [False]
# ['Charlie', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Adam', 'saw', 'three', 'dogs', 'and', 'Jimmy', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['Rose', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Wendy', 'two', '.'] [False]
# ['Michelle', 'saw', 'three', 'dogs', 'and', 'Albert', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Linda', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Anthony', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Brian', 'two', '.'] [False]
# ['Frederick', 'saw', 'three', 'dogs', 'and', 'Chris', 'two', '.'] [False]
# ['Ralph', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Janet', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Peter', 'two', '.'] [False]
# ['Amanda', 'saw', 'three', 'dogs', 'and', 'Bruce', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Katie', 'two', '.'] [False]
# ['Christine', 'saw', 'three', 'dogs', 'and', 'Ken', 'two', '.'] [False]
# ['Billy', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Ron', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Caroline', 'two', '.'] [False]
# ['Peter', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Edward', 'saw', 'three', 'dogs', 'and', 'Francis', 'two', '.'] [False]
# ['Carolyn', 'saw', 'three', 'dogs', 'and', 'Kathy', 'two', '.'] [False]
# ['Julie', 'saw', 'three', 'dogs', 'and', 'Mike', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Martha', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Keith', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Lauren', 'saw', 'three', 'dogs', 'and', 'Dick', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'Michelle', 'two', '.'] [False]
# ['Sally', 'saw', 'three', 'dogs', 'and', 'Alice', 'two', '.'] [False]
# ['Catherine', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Billy', 'two', '.'] [False]
# ['Alison', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'John', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Martha', 'two', '.'] [False]
# ['Julia', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Jennifer', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['Lynn', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Julie', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Mary', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'Jonathan', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Katie', 'two', '.'] [False]
# ['Ron', 'saw', 'three', 'dogs', 'and', 'Patrick', 'two', '.'] [False]
# ['Philip', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'George', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Alan', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Keith', 'two', '.'] [False]
# ['Christine', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Ray', 'saw', 'three', 'dogs', 'and', 'Barbara', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Margaret', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Roger', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Billy', 'saw', 'three', 'dogs', 'and', 'Colin', 'two', '.'] [False]
# ['Sarah', 'saw', 'three', 'dogs', 'and', 'Victoria', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Cynthia', 'two', '.'] [False]
# ['Edwin', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Hugh', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Julia', 'saw', 'three', 'dogs', 'and', 'Richard', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Emma', 'saw', 'three', 'dogs', 'and', 'John', 'two', '.'] [False]
# ['Carol', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Harold', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Sally', 'two', '.'] [False]
# ['Susan', 'saw', 'three', 'dogs', 'and', 'Rose', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Frances', 'saw', 'three', 'dogs', 'and', 'Harriet', 'two', '.'] [False]
# ['Frederick', 'saw', 'three', 'dogs', 'and', 'Jim', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Anna', 'two', '.'] [False]
# ['Catherine', 'saw', 'three', 'dogs', 'and', 'Lynn', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Maria', 'saw', 'three', 'dogs', 'and', 'Edward', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Evelyn', 'two', '.'] [False]
# ['Alison', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Jerry', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Judy', 'two', '.'] [False]
# ['Harold', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Steven', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Hugh', 'saw', 'three', 'dogs', 'and', 'Richard', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Michael', 'two', '.'] [False]
# ['Carolyn', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Fiona', 'saw', 'three', 'dogs', 'and', 'Janet', 'two', '.'] [False]
# ['Lisa', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Donald', 'saw', 'three', 'dogs', 'and', 'Katie', 'two', '.'] [False]
# ['Jim', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Grace', 'saw', 'three', 'dogs', 'and', 'Sarah', 'two', '.'] [False]
# ['Joan', 'saw', 'three', 'dogs', 'and', 'Paul', 'two', '.'] [False]
# ['Jessica', 'saw', 'three', 'dogs', 'and', 'Fred', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Laura', 'two', '.'] [False]
# ['Pamela', 'saw', 'three', 'dogs', 'and', 'Joe', 'two', '.'] [False]
# ['Simon', 'saw', 'three', 'dogs', 'and', 'Ken', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Ruth', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Benjamin', 'saw', 'three', 'dogs', 'and', 'Joe', 'two', '.'] [False]
# ['David', 'saw', 'three', 'dogs', 'and', 'Don', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Kate', 'two', '.'] [False]
# ['Donna', 'saw', 'three', 'dogs', 'and', 'Larry', 'two', '.'] [False]
# ['Lawrence', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Anne', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Matt', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Frances', 'two', '.'] [False]
# ['Harriet', 'saw', 'three', 'dogs', 'and', 'Simon', 'two', '.'] [False]
# ['Ellen', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Jeff', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Janet', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Julie', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Marie', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Emma', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['James', 'saw', 'three', 'dogs', 'and', 'Matt', 'two', '.'] [False]
# ['Charlotte', 'saw', 'three', 'dogs', 'and', 'Lucy', 'two', '.'] [False]
# ['Lawrence', 'saw', 'three', 'dogs', 'and', 'Heather', 'two', '.'] [False]
# ['Matt', 'saw', 'three', 'dogs', 'and', 'Gary', 'two', '.'] [False]
# ['Greg', 'saw', 'three', 'dogs', 'and', 'Larry', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Virginia', 'saw', 'three', 'dogs', 'and', 'Lawrence', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Stephanie', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Adam', 'two', '.'] [False]
# ['Alfred', 'saw', 'three', 'dogs', 'and', 'Hugh', 'two', '.'] [False]
# ['Charlotte', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Henry', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Daniel', 'saw', 'three', 'dogs', 'and', 'Tom', 'two', '.'] [False]
# ['Dave', 'saw', 'three', 'dogs', 'and', 'Thomas', 'two', '.'] [False]
# ['Benjamin', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Sandra', 'saw', 'three', 'dogs', 'and', 'Janet', 'two', '.'] [False]
# ['Gary', 'saw', 'three', 'dogs', 'and', 'Christine', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'Edwin', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Matt', 'two', '.'] [False]
# ['Louise', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['George', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Victoria', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Anna', 'saw', 'three', 'dogs', 'and', 'Bruce', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Ken', 'two', '.'] [False]
# ['Steve', 'saw', 'three', 'dogs', 'and', 'Johnny', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Ed', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Richard', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Simon', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Jill', 'two', '.'] [False]
# ['Simon', 'saw', 'three', 'dogs', 'and', 'Keith', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Karen', 'two', '.'] [False]
# ['Alice', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Adam', 'saw', 'three', 'dogs', 'and', 'Ken', 'two', '.'] [False]
# ['Albert', 'saw', 'three', 'dogs', 'and', 'Harriet', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Alan', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Michael', 'saw', 'three', 'dogs', 'and', 'Arthur', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Charles', 'saw', 'three', 'dogs', 'and', 'Katie', 'two', '.'] [False]
# ['Catherine', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Leslie', 'saw', 'three', 'dogs', 'and', 'Melissa', 'two', '.'] [False]
# ['Maria', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Grace', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Ron', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Joseph', 'saw', 'three', 'dogs', 'and', 'Kenneth', 'two', '.'] [False]
# ['Mike', 'saw', 'three', 'dogs', 'and', 'Steve', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Dorothy', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Harold', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Elaine', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Daniel', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Diane', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Benjamin', 'saw', 'three', 'dogs', 'and', 'Victoria', 'two', '.'] [False]
# ['David', 'saw', 'three', 'dogs', 'and', 'Julia', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Jonathan', 'two', '.'] [False]
# ['Eleanor', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Fiona', 'saw', 'three', 'dogs', 'and', 'Joseph', 'two', '.'] [False]
# ['Ian', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['Anna', 'saw', 'three', 'dogs', 'and', 'Matt', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Henry', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Alice', 'two', '.'] [False]
# ['Ray', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Sally', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Louis', 'saw', 'three', 'dogs', 'and', 'Eric', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Jill', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]
# ['Rose', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Rose', 'saw', 'three', 'dogs', 'and', 'Joan', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Karen', 'saw', 'three', 'dogs', 'and', 'Suzanne', 'two', '.'] [False]
# ['Kim', 'saw', 'three', 'dogs', 'and', 'Francis', 'two', '.'] [False]
# ['Carl', 'saw', 'three', 'dogs', 'and', 'Angela', 'two', '.'] [False]
# ['Heather', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Dan', 'saw', 'three', 'dogs', 'and', 'Jeff', 'two', '.'] [False]
# ...
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Larry', 'two', '.'] [False]
# ['Joan', 'saw', 'three', 'dogs', 'and', 'Donna', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Joan', 'saw', 'three', 'dogs', 'and', 'Susan', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Tom', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Kathleen', 'two', '.'] [False]
# ['Stephen', 'saw', 'three', 'dogs', 'and', 'Elaine', 'two', '.'] [False]
# ['Walter', 'saw', 'three', 'dogs', 'and', 'Karen', 'two', '.'] [False]
# ['Edwin', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Edwin', 'saw', 'three', 'dogs', 'and', 'William', 'two', '.'] [False]
# ['Sally', 'saw', 'three', 'dogs', 'and', 'Bruce', 'two', '.'] [False]
# ['Virginia', 'saw', 'three', 'dogs', 'and', 'Louis', 'two', '.'] [False]
# ['Christopher', 'saw', 'three', 'dogs', 'and', 'Jonathan', 'two', '.'] [False]
# ['Keith', 'saw', 'three', 'dogs', 'and', 'Joseph', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Dan', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Catherine', 'saw', 'three', 'dogs', 'and', 'Alfred', 'two', '.'] [False]
# ['Eleanor', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Chris', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Chris', 'two', '.'] [False]
# ['Virginia', 'saw', 'three', 'dogs', 'and', 'Charles', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Sandra', 'two', '.'] [False]
# ['Eleanor', 'saw', 'three', 'dogs', 'and', 'Steven', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Carolyn', 'two', '.'] [False]
# ['Andrew', 'saw', 'three', 'dogs', 'and', 'Peter', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Jean', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Ellen', 'two', '.'] [False]
# ['Ray', 'saw', 'three', 'dogs', 'and', 'Walter', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Kathy', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'George', 'two', '.'] [False]
# ['Judith', 'saw', 'three', 'dogs', 'and', 'Cynthia', 'two', '.'] [False]
# ['Keith', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Kenneth', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Robert', 'saw', 'three', 'dogs', 'and', 'Jason', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Patricia', 'two', '.'] [False]
# ['Ruth', 'saw', 'three', 'dogs', 'and', 'Charlotte', 'two', '.'] [False]
# ['Michelle', 'saw', 'three', 'dogs', 'and', 'Donna', 'two', '.'] [False]
# ['Harry', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Florence', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Susan', 'two', '.'] [False]
# ['Lucy', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Harry', 'two', '.'] [False]
# ['Jason', 'saw', 'three', 'dogs', 'and', 'Kelly', 'two', '.'] [False]
# ['Wendy', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Lynn', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Bill', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Florence', 'two', '.'] [False]
# ['Lauren', 'saw', 'three', 'dogs', 'and', 'Judith', 'two', '.'] [False]
# ['Nicole', 'saw', 'three', 'dogs', 'and', 'Al', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'John', 'two', '.'] [False]
# ['Sue', 'saw', 'three', 'dogs', 'and', 'Jane', 'two', '.'] [False]
# ['Kathryn', 'saw', 'three', 'dogs', 'and', 'Edith', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Roy', 'two', '.'] [False]
# ['Katherine', 'saw', 'three', 'dogs', 'and', 'Susan', 'two', '.'] [False]
# ['Louise', 'saw', 'three', 'dogs', 'and', 'Elizabeth', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Ben', 'saw', 'three', 'dogs', 'and', 'Jay', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Louis', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Edith', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Francis', 'saw', 'three', 'dogs', 'and', 'Anthony', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'William', 'two', '.'] [False]
# ['Kathryn', 'saw', 'three', 'dogs', 'and', 'David', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Edith', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Kathryn', 'two', '.'] [False]
# ['Annie', 'saw', 'three', 'dogs', 'and', 'Eleanor', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Margaret', 'saw', 'three', 'dogs', 'and', 'Emma', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Brian', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Alexandra', 'two', '.'] [False]
# ['Alexandra', 'saw', 'three', 'dogs', 'and', 'Sandra', 'two', '.'] [False]
# ['Virginia', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Kate', 'two', '.'] [False]
# ['Edith', 'saw', 'three', 'dogs', 'and', 'Anne', 'two', '.'] [False]
# ['Judith', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Ruth', 'saw', 'three', 'dogs', 'and', 'Julie', 'two', '.'] [False]
# ['Anna', 'saw', 'three', 'dogs', 'and', 'Philip', 'two', '.'] [False]
# ['Ed', 'saw', 'three', 'dogs', 'and', 'Brian', 'two', '.'] [False]
# ['Keith', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Carol', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Judy', 'saw', 'three', 'dogs', 'and', 'Mark', 'two', '.'] [False]
# ['Anthony', 'saw', 'three', 'dogs', 'and', 'Ray', 'two', '.'] [False]
# ['Stephen', 'saw', 'three', 'dogs', 'and', 'Betty', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Melissa', 'two', '.'] [False]
# ['Helen', 'saw', 'three', 'dogs', 'and', 'Caroline', 'two', '.'] [False]
# ['Dick', 'saw', 'three', 'dogs', 'and', 'Jason', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Bob', 'saw', 'three', 'dogs', 'and', 'Jack', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Thomas', 'two', '.'] [False]
# ['Nancy', 'saw', 'three', 'dogs', 'and', 'Laura', 'two', '.'] [False]
# ['Louise', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Cynthia', 'saw', 'three', 'dogs', 'and', 'Claire', 'two', '.'] [False]
# ['Jimmy', 'saw', 'three', 'dogs', 'and', 'George', 'two', '.'] [False]
# ['Victoria', 'saw', 'three', 'dogs', 'and', 'Ann', 'two', '.'] [False]
# ['Samuel', 'saw', 'three', 'dogs', 'and', 'Fiona', 'two', '.'] [False]
# ['Diane', 'saw', 'three', 'dogs', 'and', 'Colin', 'two', '.'] [False]
# ['Jason', 'saw', 'three', 'dogs', 'and', 'Hugh', 'two', '.'] [False]
# ['Michelle', 'saw', 'three', 'dogs', 'and', 'Jessica', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Martin', 'saw', 'three', 'dogs', 'and', 'Ron', 'two', '.'] [False]
# ['Richard', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Sophie', 'saw', 'three', 'dogs', 'and', 'Alison', 'two', '.'] [False]
# ['Catherine', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Tom', 'two', '.'] [False]
# ['Nick', 'saw', 'three', 'dogs', 'and', 'Jerry', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Carl', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Janet', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Samuel', 'two', '.'] [False]
# ['Johnny', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Kevin', 'saw', 'three', 'dogs', 'and', 'Patrick', 'two', '.'] [False]
# ['Dan', 'saw', 'three', 'dogs', 'and', 'Claire', 'two', '.'] [False]
# ['Melissa', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Lauren', 'saw', 'three', 'dogs', 'and', 'Catherine', 'two', '.'] [False]
# ['Maria', 'saw', 'three', 'dogs', 'and', 'Evelyn', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Joe', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Andrea', 'saw', 'three', 'dogs', 'and', 'Keith', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Roy', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Brian', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Chris', 'two', '.'] [False]
# ['Jack', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Daniel', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Don', 'saw', 'three', 'dogs', 'and', 'Emily', 'two', '.'] [False]
# ['Ryan', 'saw', 'three', 'dogs', 'and', 'Charles', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Roger', 'two', '.'] [False]
# ['Nick', 'saw', 'three', 'dogs', 'and', 'Diana', 'two', '.'] [False]
# ['Scott', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Mary', 'saw', 'three', 'dogs', 'and', 'Virginia', 'two', '.'] [False]
# ['Judy', 'saw', 'three', 'dogs', 'and', 'Katherine', 'two', '.'] [False]
# ['Ruth', 'saw', 'three', 'dogs', 'and', 'Ellen', 'two', '.'] [False]
# ['Amanda', 'saw', 'three', 'dogs', 'and', 'Nicole', 'two', '.'] [False]
# ['Kelly', 'saw', 'three', 'dogs', 'and', 'Robert', 'two', '.'] [False]
# ['Maria', 'saw', 'three', 'dogs', 'and', 'Kathryn', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Fred', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Dorothy', 'two', '.'] [False]
# ['Jean', 'saw', 'three', 'dogs', 'and', 'Grace', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Helen', 'two', '.'] [False]
# ['Charlotte', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Annie', 'saw', 'three', 'dogs', 'and', 'Edward', 'two', '.'] [False]
# ['Sarah', 'saw', 'three', 'dogs', 'and', 'Sara', 'two', '.'] [False]
# ['Anthony', 'saw', 'three', 'dogs', 'and', 'Tony', 'two', '.'] [False]
# ['Henry', 'saw', 'three', 'dogs', 'and', 'Nicole', 'two', '.'] [False]
# ['Al', 'saw', 'three', 'dogs', 'and', 'Edward', 'two', '.'] [False]
# ['Margaret', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Howard', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Thomas', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Claire', 'saw', 'three', 'dogs', 'and', 'Frederick', 'two', '.'] [False]
# ['Jim', 'saw', 'three', 'dogs', 'and', 'Rebecca', 'two', '.'] [False]
# ['Evelyn', 'saw', 'three', 'dogs', 'and', 'Dick', 'two', '.'] [False]
# ['Jim', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Paul', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Sara', 'saw', 'three', 'dogs', 'and', 'Scott', 'two', '.'] [False]
# ['Ann', 'saw', 'three', 'dogs', 'and', 'Marilyn', 'two', '.'] [False]
# ['Louis', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Fiona', 'saw', 'three', 'dogs', 'and', 'Arthur', 'two', '.'] [False]
# ['Sarah', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Paul', 'two', '.'] [False]
# ['Katie', 'saw', 'three', 'dogs', 'and', 'Ashley', 'two', '.'] [False]
# ['Marilyn', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['Maria', 'saw', 'three', 'dogs', 'and', 'Patrick', 'two', '.'] [False]
# ['Kate', 'saw', 'three', 'dogs', 'and', 'Ben', 'two', '.'] [False]
# ['Colin', 'saw', 'three', 'dogs', 'and', 'James', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Andrew', 'two', '.'] [False]
# ['Billy', 'saw', 'three', 'dogs', 'and', 'Robin', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Nancy', 'two', '.'] [False]
# ['Alex', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Martin', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Edith', 'saw', 'three', 'dogs', 'and', 'Christine', 'two', '.'] [False]
# ['Jean', 'saw', 'three', 'dogs', 'and', 'Annie', 'two', '.'] [False]
# ['Linda', 'saw', 'three', 'dogs', 'and', 'Benjamin', 'two', '.'] [False]
# ['Diana', 'saw', 'three', 'dogs', 'and', 'Leslie', 'two', '.'] [False]
# ['Judy', 'saw', 'three', 'dogs', 'and', 'Steve', 'two', '.'] [False]
# ['Sam', 'saw', 'three', 'dogs', 'and', 'Kim', 'two', '.'] [False]
# ['George', 'saw', 'three', 'dogs', 'and', 'Harold', 'two', '.'] [False]
# ['Ken', 'saw', 'three', 'dogs', 'and', 'Greg', 'two', '.'] [False]
# ['Mark', 'saw', 'three', 'dogs', 'and', 'Amanda', 'two', '.'] [False]
# ['Jean', 'saw', 'three', 'dogs', 'and', 'Elizabeth', 'two', '.'] [False]
# ['Robin', 'saw', 'three', 'dogs', 'and', 'Margaret', 'two', '.'] [False]
# ['George', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Al', 'saw', 'three', 'dogs', 'and', 'Ralph', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Roy', 'two', '.'] [False]
# ['Jay', 'saw', 'three', 'dogs', 'and', 'Alex', 'two', '.'] [False]
# ['Margaret', 'saw', 'three', 'dogs', 'and', 'Matt', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Sharon', 'two', '.'] [False]
# ['Caroline', 'saw', 'three', 'dogs', 'and', 'Pamela', 'two', '.'] [False]
# ['Steven', 'saw', 'three', 'dogs', 'and', 'Howard', 'two', '.'] [False]
# ['Deborah', 'saw', 'three', 'dogs', 'and', 'Dick', 'two', '.'] [False]
# ['Laura', 'saw', 'three', 'dogs', 'and', 'Christine', 'two', '.'] [False]
# ['Tony', 'saw', 'three', 'dogs', 'and', 'Patricia', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Bobby', 'two', '.'] [False]
# ['Kelly', 'saw', 'three', 'dogs', 'and', 'Mark', 'two', '.'] [False]
# ['Florence', 'saw', 'three', 'dogs', 'and', 'Al', 'two', '.'] [False]
# ['Laura', 'saw', 'three', 'dogs', 'and', 'Nick', 'two', '.'] [False]
# ['Frank', 'saw', 'three', 'dogs', 'and', 'Lisa', 'two', '.'] [False]
# ['Robert', 'saw', 'three', 'dogs', 'and', 'Andrew', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'Alexander', 'two', '.'] [False]
# ['Jane', 'saw', 'three', 'dogs', 'and', 'Louise', 'two', '.'] [False]
# ['Paul', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]
# ['Ian', 'saw', 'three', 'dogs', 'and', 'Maria', 'two', '.'] [False]
# ['John', 'saw', 'three', 'dogs', 'and', 'Tim', 'two', '.'] [False]
# ['Alexander', 'saw', 'three', 'dogs', 'and', 'Harry', 'two', '.'] [False]
# ['Ashley', 'saw', 'three', 'dogs', 'and', 'Martha', 'two', '.'] [False]
# ['Bobby', 'saw', 'three', 'dogs', 'and', 'Al', 'two', '.'] [False]
# ['James', 'saw', 'three', 'dogs', 'and', 'Stephen', 'two', '.'] [False]
# ['Harry', 'saw', 'three', 'dogs', 'and', 'Michelle', 'two', '.'] [False]
# ['Roger', 'saw', 'three', 'dogs', 'and', 'Sally', 'two', '.'] [False]
# ['Barbara', 'saw', 'three', 'dogs', 'and', 'Elizabeth', 'two', '.'] [False]
# ['Matthew', 'saw', 'three', 'dogs', 'and', 'Deborah', 'two', '.'] [False]
# ['Charles', 'saw', 'three', 'dogs', 'and', 'Florence', 'two', '.'] [False]
# ['Bruce', 'saw', 'three', 'dogs', 'and', 'Amy', 'two', '.'] [False]
# ['Roy', 'saw', 'three', 'dogs', 'and', 'Bob', 'two', '.'] [False]
# ['Patrick', 'saw', 'three', 'dogs', 'and', 'William', 'two', '.'] [False]
# ['Kathy', 'saw', 'three', 'dogs', 'and', 'Jill', 'two', '.'] [False]
# ['Alice', 'saw', 'three', 'dogs', 'and', 'Ryan', 'two', '.'] [False]
# ['Eric', 'saw', 'three', 'dogs', 'and', 'Donna', 'two', '.'] [False]
# ['Arthur', 'saw', 'three', 'dogs', 'and', 'Mark', 'two', '.'] [False]
# ['Gary', 'saw', 'three', 'dogs', 'and', 'Kathy', 'two', '.'] [False]
# ['Martin', 'saw', 'three', 'dogs', 'and', 'Rachel', 'two', '.'] [False]

# %%
# the following piece of code was adapted from https://howtodoinjava.com/examples/python-print-to-file/
import sys
original_stdout = sys.stdout  
 
with open('Predictions_BiLSTM/false_sentences_Predicate_Ellipsis.txt', 'a') as f:
    sys.stdout = f 
    print(test.summary(format_example_fn=format_srl), file = f)
    # Reset the standard output
    sys.stdout = original_stdout
