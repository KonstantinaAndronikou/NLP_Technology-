# %% [markdown]
# ### Konstantina Andronikou

# %% [markdown]
# ## Comparison with notebook with_conjuction

# %% [markdown]
# ## This noteboook is implementing a sentence without a conjuction

# %%
from allennlp_models.pretrained import load_predictor

# %%
import checklist
import logging 
import csv
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect

# %%
from checklist.pred_wrapper import PredictorWrapper

# %%
# To remove all warnings
logging.getLogger('allennlp.common.params').disabled = True 
logging.getLogger('allennlp.nn.initializers').disabled = True 
logging.getLogger('allennlp.modules.token_embedders.embedding').disabled = True 
logging.getLogger('urllib3.connectionpool').disabled = True 
logging.getLogger('allennlp.common.plugins').disabled = True 
logging.getLogger('allennlp.common.model_card').disabled = True 
logging.getLogger('allennlp.models.archival').disabled = True 
logging.getLogger('allennlp.data.vocabulary').disabled = True 
logging.getLogger('cached_path').disabled = True
srl_predictor = load_predictor('structured-prediction-srl')
output = srl_predictor.predict("Someone killed Mary.")
output
# Out:
# {'verbs': [{'verb': 'killed',
#    'description': '[ARG0: Someone] [V: killed] [ARG1: Mary] .',
#    'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'O']}],
#  'words': ['Someone', 'killed', 'Mary', '.']}

# %%
def predict_srl(data):
    
    pred = []
    for d in data:
        pred.append(srl_predictor.predict(d))
    return pred

predict_and_conf = PredictorWrapper.wrap_predict(predict_srl)

# %%
d = ["Someone killed Mary."]
pred = predict_and_conf(d)
pred
# Out:
# ([{'verbs': [{'verb': 'killed',
#      'description': '[ARG0: Someone] [V: killed] [ARG1: Mary] .',
#      'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'O']}],
#    'words': ['Someone', 'killed', 'Mary', '.']}],
#  array([1.]))

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    
    return pred['verbs'][0]['description']

# %%
def get_arg(pred, arg_target='ARG1'):
    predicate_arguments = pred['verbs'][0]
    #print(predicate_arguments)
    words = pred['words']
    tags = predicate_arguments['tags']
    
    arg_list = []
    for t, w in zip(tags, words):
        arg = t
        if '-' in t:
            arg = t.split('-')[1]
        if arg == arg_target:
            arg_list.append(w)
    arg_set = set(arg_list)
    return arg_set

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    results = []
    predicate_structure = pred['verbs'][0]['description']
        
    return predicate_structure

# %%
def found_arg1_people(x, pred, conf, label=None, meta=None):

    people = set([meta['first_name'],meta['last_name']])
    arg_1 = get_arg(pred, arg_target='ARG1')

    if arg_1 == people:
        pass_ = True
    else:
        pass_ = False
    return pass_


expect_arg1 = Expect.single(found_arg1_people)

# %%
editor = Editor()

# create examples
t = editor.template('Someone killed {first_name} {last_name}.', meta=True, nsamples=1000, remove_duplicates = True)

#print(type(t))

for k, v in t.items():
    print(k, v)
# Out:
# meta [{'first_name': 'Carolyn', 'last_name': 'Richardson'}, {'first_name': 'Margaret', 'last_name': 'Stevens'}, {'first_name': 'Thomas', 'last_name': 'Gray'}, {'first_name': 'Margaret', 'last_name': 'Davis'}, {'first_name': 'Fiona', 'last_name': 'Harrison'}, {'first_name': 'Paul', 'last_name': 'Jordan'}, {'first_name': 'Evelyn', 'last_name': 'Ward'}, {'first_name': 'Karen', 'last_name': 'Thomas'}, {'first_name': 'William', 'last_name': 'Young'}, {'first_name': 'Lisa', 'last_name': 'Alexander'}, {'first_name': 'Kenneth', 'last_name': 'Hall'}, {'first_name': 'Virginia', 'last_name': 'Peterson'}, {'first_name': 'Leslie', 'last_name': 'Jones'}, {'first_name': 'Lisa', 'last_name': 'Scott'}, {'first_name': 'Samuel', 'last_name': 'Gordon'}, {'first_name': 'Linda', 'last_name': 'Walker'}, {'first_name': 'Marie', 'last_name': 'Harrison'}, {'first_name': 'Johnny', 'last_name': 'Fisher'}, {'first_name': 'Grace', 'last_name': 'Ross'}, {'first_name': 'Edwin', 'last_name': 'Carter'}, {'first_name': 'Catherine', 'last_name': 'Stone'}, {'first_name': 'Dick', 'last_name': 'Ryan'}, {'first_name': 'Sara', 'last_name': 'Williams'}, {'first_name': 'Mike', 'last_name': 'Johnson'}, {'first_name': 'Andrew', 'last_name': 'Gray'}, {'first_name': 'Diane', 'last_name': "O'Brien"}, {'first_name': 'Sophie', 'last_name': 'Gordon'}, {'first_name': 'Rose', 'last_name': 'Fisher'}, {'first_name': 'Alexander', 'last_name': 'Harrison'}, {'first_name': 'Nicole', 'last_name': 'Edwards'}, {'first_name': 'Lisa', 'last_name': 'Hart'}, {'first_name': 'Kelly', 'last_name': 'Phillips'}, {'first_name': 'Ben', 'last_name': 'Jordan'}, {'first_name': 'Jason', 'last_name': 'Kennedy'}, {'first_name': 'Donald', 'last_name': 'Hart'}, {'first_name': 'Kathleen', 'last_name': 'Nelson'}, {'first_name': 'Ray', 'last_name': 'Thompson'}, {'first_name': 'Mark', 'last_name': 'Harris'}, {'first_name': 'Catherine', 'last_name': 'Ford'}, {'first_name': 'Deborah', 'last_name': 'Price'}, {'first_name': 'Emily', 'last_name': 'Lewis'}, {'first_name': 'Florence', 'last_name': 'Stewart'}, {'first_name': 'Dave', 'last_name': 'Brown'}, {'first_name': 'Edward', 'last_name': 'Ryan'}, {'first_name': 'Samuel', 'last_name': 'Scott'}, {'first_name': 'Ann', 'last_name': 'Harrison'}, {'first_name': 'Jeff', 'last_name': 'Allen'}, {'first_name': 'Charlotte', 'last_name': 'James'}, {'first_name': 'Angela', 'last_name': 'Kennedy'}, {'first_name': 'Evelyn', 'last_name': 'Richardson'}, {'first_name': 'Jim', 'last_name': 'Bell'}, {'first_name': 'Dan', 'last_name': 'Carter'}, {'first_name': 'Mark', 'last_name': 'Brooks'}, {'first_name': 'Dan', 'last_name': 'Kennedy'}, {'first_name': 'Don', 'last_name': 'Henderson'}, {'first_name': 'Dave', 'last_name': 'Cooper'}, {'first_name': 'Charles', 'last_name': 'Martin'}, {'first_name': 'Ruth', 'last_name': 'Jones'}, {'first_name': 'Jerry', 'last_name': 'Reynolds'}, {'first_name': 'Andrew', 'last_name': 'Kennedy'}, {'first_name': 'Francis', 'last_name': 'Sullivan'}, {'first_name': 'Howard', 'last_name': 'Collins'}, {'first_name': 'Linda', 'last_name': "O'Brien"}, {'first_name': 'Harriet', 'last_name': 'Bell'}, {'first_name': 'Edwin', 'last_name': 'Roberts'}, {'first_name': 'Joan', 'last_name': 'Harrison'}, {'first_name': 'Rose', 'last_name': 'Cooper'}, {'first_name': 'Rachel', 'last_name': 'Clarke'}, {'first_name': 'Kenneth', 'last_name': 'Carter'}, {'first_name': 'Florence', 'last_name': 'Gray'}, {'first_name': 'Daniel', 'last_name': 'Wright'}, {'first_name': 'Joan', 'last_name': 'Ryan'}, {'first_name': 'Robert', 'last_name': 'Cook'}, {'first_name': 'Virginia', 'last_name': 'Bailey'}, {'first_name': 'Jack', 'last_name': 'Wilson'}, {'first_name': 'Emily', 'last_name': 'Collins'}, {'first_name': 'Alexandra', 'last_name': 'Russell'}, {'first_name': 'Tim', 'last_name': 'Turner'}, {'first_name': 'Julia', 'last_name': 'Hughes'}, {'first_name': 'Howard', 'last_name': 'Sullivan'}, {'first_name': 'Ellen', 'last_name': 'Hamilton'}, {'first_name': 'Thomas', 'last_name': 'Kennedy'}, {' ...
# data ['Someone killed Carolyn Richardson.', 'Someone killed Margaret Stevens.', 'Someone killed Thomas Gray.', 'Someone killed Margaret Davis.', 'Someone killed Fiona Harrison.', 'Someone killed Paul Jordan.', 'Someone killed Evelyn Ward.', 'Someone killed Karen Thomas.', 'Someone killed William Young.', 'Someone killed Lisa Alexander.', 'Someone killed Kenneth Hall.', 'Someone killed Virginia Peterson.', 'Someone killed Leslie Jones.', 'Someone killed Lisa Scott.', 'Someone killed Samuel Gordon.', 'Someone killed Linda Walker.', 'Someone killed Marie Harrison.', 'Someone killed Johnny Fisher.', 'Someone killed Grace Ross.', 'Someone killed Edwin Carter.', 'Someone killed Catherine Stone.', 'Someone killed Dick Ryan.', 'Someone killed Sara Williams.', 'Someone killed Mike Johnson.', 'Someone killed Andrew Gray.', "Someone killed Diane O'Brien.", 'Someone killed Sophie Gordon.', 'Someone killed Rose Fisher.', 'Someone killed Alexander Harrison.', 'Someone killed Nicole Edwards.', 'Someone killed Lisa Hart.', 'Someone killed Kelly Phillips.', 'Someone killed Ben Jordan.', 'Someone killed Jason Kennedy.', 'Someone killed Donald Hart.', 'Someone killed Kathleen Nelson.', 'Someone killed Ray Thompson.', 'Someone killed Mark Harris.', 'Someone killed Catherine Ford.', 'Someone killed Deborah Price.', 'Someone killed Emily Lewis.', 'Someone killed Florence Stewart.', 'Someone killed Dave Brown.', 'Someone killed Edward Ryan.', 'Someone killed Samuel Scott.', 'Someone killed Ann Harrison.', 'Someone killed Jeff Allen.', 'Someone killed Charlotte James.', 'Someone killed Angela Kennedy.', 'Someone killed Evelyn Richardson.', 'Someone killed Jim Bell.', 'Someone killed Dan Carter.', 'Someone killed Mark Brooks.', 'Someone killed Dan Kennedy.', 'Someone killed Don Henderson.', 'Someone killed Dave Cooper.', 'Someone killed Charles Martin.', 'Someone killed Ruth Jones.', 'Someone killed Jerry Reynolds.', 'Someone killed Andrew Kennedy.', 'Someone killed Francis Sullivan.', 'Someone killed Howard Collins.', "Someone killed Linda O'Brien.", 'Someone killed Harriet Bell.', 'Someone killed Edwin Roberts.', 'Someone killed Joan Harrison.', 'Someone killed Rose Cooper.', 'Someone killed Rachel Clarke.', 'Someone killed Kenneth Carter.', 'Someone killed Florence Gray.', 'Someone killed Daniel Wright.', 'Someone killed Joan Ryan.', 'Someone killed Robert Cook.', 'Someone killed Virginia Bailey.', 'Someone killed Jack Wilson.', 'Someone killed Emily Collins.', 'Someone killed Alexandra Russell.', 'Someone killed Tim Turner.', 'Someone killed Julia Hughes.', 'Someone killed Howard Sullivan.', 'Someone killed Ellen Hamilton.', 'Someone killed Thomas Kennedy.', 'Someone killed Joan Miller.', 'Someone killed Ken Wood.', 'Someone killed Ben Johnson.', 'Someone killed Paul Clark.', 'Someone killed Kate Evans.', 'Someone killed Bobby Brown.', 'Someone killed Greg Shaw.', 'Someone killed Dave Cook.', 'Someone killed Alex Scott.', 'Someone killed Alex Hart.', 'Someone killed Marie Reed.', 'Someone killed Jill Reynolds.', 'Someone killed Don Edwards.', 'Someone killed Henry Baker.', 'Someone killed Jason Alexander.', 'Someone killed Rose Bailey.', 'Someone killed Jeff Miller.', 'Someone killed Colin Harris.', 'Someone killed John Murray.', 'Someone killed Jonathan Bell.', 'Someone killed Kathryn Perry.', 'Someone killed Edith Robertson.', 'Someone killed Matt Jackson.', 'Someone killed Francis Jones.', 'Someone killed Grace Walker.', 'Someone killed Ron Miller.', 'Someone killed Leslie Alexander.', 'Someone killed Ray Jackson.', 'Someone killed Jimmy Walker.', 'Someone killed Jack Brown.', 'Someone killed Ron Brooks.', 'Someone killed Alexander Jones.', 'Someone killed Kenneth Shaw.', 'Someone killed Bill Edwards.', 'Someone killed Susan Moore.', 'Someone killed Jessica Fisher.', 'Someone killed Kathryn Crawford.', 'Someone killed Jill Smith.', 'Someone killed Bob Ross.', 'Someone killed Suzanne Thomas.', 'Someone killed Roger Lewis.', 'Someone killed Linda ...

# %%
with open('Dataset_BiLSTM/Without_conjuction.txt', 'w') as f:
    print(t.data, file = f)

# %%
# initialize a rest object
test = MFT(**t, name = 'detect_arg1_name_default_position', expect=expect_arg1)
output = test.run(predict_and_conf)
test.summary(format_example_fn=format_srl)
i = test.results['preds']
expect_for_i = test.results['expect_results']
with open ('Output_BiLSTM/predictions_without_con.csv','w') as f:
    writer = csv.writer(f)
    for result, exp in zip(i, expect_for_i):
        
        case = result['words']
        exp = exp
        writer.writerow([case, exp])
        print(case,exp)
# Out:
# Predicting 1000 examples
# Test cases:      1000
# Fails (rate):    4 (0.4%)
#
# Example fails:
# [ARG0: Someone] [V: killed] [ARG1: Catherine] [ARGM-TMP: Stone] .
# ----
# [ARG0: Someone] [V: killed] [ARG1: Simon] [ARGM-TMP: Stone] .
# ----
# [ARG0: Someone] [V: killed] [ARG1: Amy] [ARGM-TMP: Stone] .
# ----
# ['Someone', 'killed', 'Carolyn', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Thomas', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Fiona', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Paul', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Evelyn', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Karen', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'William', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Samuel', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Linda', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Marie', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Johnny', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Grace', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Stone', '.'] [False]
# ['Someone', 'killed', 'Dick', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Diane', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Sophie', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Alexander', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Nicole', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Kelly', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Donald', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Kathleen', 'Nelson', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Mark', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Deborah', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Emily', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Dave', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Edward', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Samuel', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Jeff', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'James', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Evelyn', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Mark', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Don', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Dave', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Charles', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Jerry', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Linda', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Rachel', 'Clarke', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Daniel', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Jack', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Emily', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Julia', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Thomas', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Ken', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Paul', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Bobby', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Greg', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Dave', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Marie', 'Reed', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Don', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Henry', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Jeff', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Colin', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'John', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Jonathan', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Kathryn', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Matt', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Grace', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Ron', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Jimmy', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Jack', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Ron', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Alexander', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Bill', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Susan', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Jessica', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Kathryn', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Bob', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Linda', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Arthur', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Diana', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Melissa', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'George', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Stephen', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Roy', 'Clarke', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Dick', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Christine', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Emma', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Anne', 'Morgan', '.'] [ True]
# ['Someone', 'killed', 'Ron', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Gary', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Anthony', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Eleanor', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Diana', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Bill', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Jonathan', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Edward', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Alfred', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Adam', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'George', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Helen', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'James', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Hugh', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Emily', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Bob', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'James', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'John', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Kim', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Sue', 'Hill', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Kathryn', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Ed', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Stephanie', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Christine', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Jean', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Harry', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Frances', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Melissa', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Linda', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Maria', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Frank', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Katherine', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Katherine', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Alexander', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Andrea', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'John', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Nicole', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Martha', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Dick', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Ken', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Jessica', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Jean', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Anne', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'White', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'John', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Reed', '.'] [ True]
# ['Someone', 'killed', 'Donald', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Bill', 'Marshall', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Julia', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Roy', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Steve', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Samuel', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'James', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Tony', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Betty', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Rebecca', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Christopher', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Hugh', 'Nelson', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Graham', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Marshall', '.'] [ True]
# ['Someone', 'killed', 'Eric', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Ed', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Roy', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Janet', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Christopher', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Anne', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Helen', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Stone', '.'] [False]
# ['Someone', 'killed', 'Alison', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Jean', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Fiona', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Hill', '.'] [ True]
# ['Someone', 'killed', 'Samuel', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Emma', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Susan', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Katie', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Sue', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Stephen', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Maria', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Brian', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Jack', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Andrea', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Anna', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Nick', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'William', 'James', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Lucy', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Arthur', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Lynn', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Victoria', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Bruce', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'John', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Ed', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Victoria', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Hill', '.'] [ True]
# ['Someone', 'killed', 'Richard', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Tony', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Martin', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Christopher', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Steve', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Tom', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Alison', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Charlie', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Patricia', 'Clarke', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Stephen', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Carol', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Emily', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Matt', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Alison', 'Marshall', '.'] [ True]
# ['Someone', 'killed', 'Janet', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Carol', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Nicole', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Julie', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Harold', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Rebecca', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Walter', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Marie', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Rachel', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Marie', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Carol', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Steven', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Roy', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'Alan', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Stone', '.'] [False]
# ['Someone', 'killed', 'Bobby', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Rebecca', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Henry', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Jonathan', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Martha', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Kathy', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Rachel', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Steven', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Johnny', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Morgan', '.'] [ True]
# ['Someone', 'killed', 'Mark', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Scott', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Richard', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Jessica', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Steven', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'James', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Martin', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Graham', '.'] [ True]
# ['Someone', 'killed', 'Kathryn', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Lucy', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Kelly', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Bob', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Bobby', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'George', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Roy', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Dorothy', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'James', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Nancy', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Kathleen', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Bruce', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Elaine', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Ken', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Frances', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Daniel', 'Graham', '.'] [ True]
# ['Someone', 'killed', 'Henry', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Jeff', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Sarah', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Charles', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Ron', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Hugh', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Melissa', 'Marshall', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Jeff', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Susan', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Tony', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Donna', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'James', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Melissa', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Sarah', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Nicole', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Kathleen', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Joe', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'Sophie', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Melissa', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'James', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Paul', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Price', '.'] [ True]
# ['Someone', 'killed', 'James', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Sophie', 'Graham', '.'] [ True]
# ['Someone', 'killed', 'Kathy', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Adam', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Jean', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Frances', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Henderson', '.'] [False]
# ['Someone', 'killed', 'Matt', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Jill', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'David', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Frederick', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Patricia', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Grace', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Frank', 'White', '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Dick', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Ben', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Christine', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Joe', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Alan', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Anne', 'Reed', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Alfred', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Edward', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Katherine', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Fiona', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Jean', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Elaine', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Sandra', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Gary', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Christine', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Daniel', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'John', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Fred', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Larry', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Janet', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Elaine', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Hugh', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Ron', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Jessica', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Victoria', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Tom', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Kelly', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Stephen', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Karen', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Jack', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Matt', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Alan', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Rebecca', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Evelyn', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Alison', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Kathleen', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Philip', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Fred', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'Janet', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Eleanor', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Dave', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Andrea', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Frank', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Nelson', '.'] [ True]
# ['Someone', 'killed', 'Katie', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Bobby', 'Morgan', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Judith', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Carol', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Helen', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Kevin', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Anna', 'Henderson', '.'] [ True]
# ['Someone', 'killed', 'Sandra', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Tony', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Thomas', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Nick', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Elaine', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'David', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Patricia', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Helen', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Steven', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Lawrence', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Brian', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Amanda', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'Lucy', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Dan', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Alice', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Sara', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Harry', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Bruce', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Hugh', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Howard', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Eleanor', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Matt', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'King', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Ward', '.'] [ True]
# ['Someone', 'killed', 'Anne', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Harry', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Greg', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Sarah', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Rose', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Mason', '.'] [ True]
# ['Someone', 'killed', 'Fiona', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'George', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Henry', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Florence', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Dorothy', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Emily', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Bill', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Edward', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Kim', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Clarke', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Bill', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Victoria', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Martha', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Amy', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Tom', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Betty', 'Clarke', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'King', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Michelle', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Lynn', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Cook', '.'] [ True]
# ['Someone', 'killed', 'Fred', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Christopher', 'King', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Arthur', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Sally', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Michelle', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'James', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Joe', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Ruth', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Walter', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Joe', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Greg', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Jeff', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Anthony', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Dick', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Jane', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Kathryn', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Jones', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Greg', 'Jordan', '.'] [ True]
# ['Someone', 'killed', 'Martin', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Price', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Nick', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Wendy', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Ross', '.'] [ True]
# ['Someone', 'killed', 'Arthur', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Dorothy', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Rebecca', 'Adams', '.'] [ True]
# ['Someone', 'killed', 'Jack', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Matthew', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'James', 'Brown', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Mary', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Albert', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Betty', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Stephen', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Johnson', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Tom', 'Harris', '.'] [ True]
# ['Someone', 'killed', 'Frederick', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Deborah', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Lucy', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'James', '.'] [ True]
# ['Someone', 'killed', 'Sue', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Rachel', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Alan', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Alfred', 'Collins', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Evans', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Mike', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Louise', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Joseph', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Jerry', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Ashley', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Reed', '.'] [ True]
# ['Someone', 'killed', 'Barbara', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Katie', 'Mason', '.'] [ True]
# ['Someone', 'killed', 'Pamela', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Scott', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Donald', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Michelle', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Ed', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Michelle', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Sam', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Alison', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Donna', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Lauren', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Al', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Kelly', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Tom', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Barbara', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Katie', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Caroline', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Jerry', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Kelly', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Larry', 'Hamilton', '.'] [ True]
# ['Someone', 'killed', 'Karen', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Henry', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Mark', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'David', 'Brooks', '.'] [ True]
# ['Someone', 'killed', 'Tony', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Nelson', '.'] [ True]
# ['Someone', 'killed', 'James', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Matthew', 'Martin', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Howard', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Taylor', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Edith', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Emma', 'James', '.'] [ True]
# ['Someone', 'killed', 'Jim', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Mitchell', '.'] [ True]
# ['Someone', 'killed', 'Brian', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Walter', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Greg', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Dick', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Claire', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'William', 'James', '.'] [ True]
# ['Someone', 'killed', 'Kim', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Alice', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Samuel', 'Anderson', '.'] [ True]
# ['Someone', 'killed', 'Martin', 'Bell', '.'] [ True]
# ['Someone', 'killed', 'Julia', 'Marshall', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Baker', '.'] [ True]
# ['Someone', 'killed', 'Emma', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Keith', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Harry', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Andrea', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Barbara', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Jay', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Charles', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Jonathan', 'Davis', '.'] [ True]
# ['Someone', 'killed', 'Richard', 'Stevens', '.'] [ True]
# ['Someone', 'killed', 'Edwin', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Stephanie', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Elizabeth', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Stephanie', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Charles', 'Cohen', '.'] [ True]
# ['Someone', 'killed', 'Lisa', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Young', '.'] [ True]
# ['Someone', 'killed', 'Walter', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Matthew', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Martha', 'Stewart', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Don', 'Wilson', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Ford', '.'] [ True]
# ['Someone', 'killed', 'Alison', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Frederick', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Sarah', 'Walker', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Martha', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Margaret', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Evelyn', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Charles', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Donald', 'Parker', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Miller', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'Clark', '.'] [ True]
# ['Someone', 'killed', 'Fred', 'Robertson', '.'] [ True]
# ['Someone', 'killed', 'Frederick', 'Robinson', '.'] [ True]
# ['Someone', 'killed', 'Carl', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Sally', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Angela', 'White', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Thomas', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Billy', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Frederick', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Alan', 'Reed', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Kathy', 'Reynolds', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Bailey', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Steven', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Harriet', 'Stone', '.'] [ True]
# ['Someone', 'killed', 'Roger', 'Hunter', '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Philip', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Thomas', 'King', '.'] [ True]
# ['Someone', 'killed', 'Charlotte', 'Ryan', '.'] [ True]
# ['Someone', 'killed', 'Simon', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Larry', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'Jackson', '.'] [ True]
# ['Someone', 'killed', 'Benjamin', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'John', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Carolyn', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Joan', 'Murphy', '.'] [ True]
# ['Someone', 'killed', 'Ellen', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Morgan', '.'] [ True]
# ['Someone', 'killed', 'Jennifer', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Joe', 'Alexander', '.'] [ True]
# ['Someone', 'killed', 'Simon', 'Coleman', '.'] [ True]
# ['Someone', 'killed', 'Ralph', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Dorothy', 'Hart', '.'] [ True]
# ['Someone', 'killed', 'Heather', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Daniel', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Francis', 'Fisher', '.'] [ True]
# ['Someone', 'killed', 'Evelyn', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Bennett', '.'] [ True]
# ['Someone', 'killed', 'Alice', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Catherine', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Chris', 'James', '.'] [ True]
# ['Someone', 'killed', 'Robin', 'Thompson', '.'] [ True]
# ['Someone', 'killed', 'Laura', 'Kennedy', '.'] [ True]
# ['Someone', 'killed', 'Lawrence', 'Rogers', '.'] [ True]
# ['Someone', 'killed', 'Diane', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Perry', '.'] [ True]
# ['Someone', 'killed', 'Ray', 'Shaw', '.'] [ True]
# ['Someone', 'killed', 'Dorothy', 'Cooper', '.'] [ True]
# ['Someone', 'killed', 'Michelle', 'Moore', '.'] [ True]
# ['Someone', 'killed', 'Victoria', 'Scott', '.'] [ True]
# ['Someone', 'killed', 'Louis', 'Hall', '.'] [ True]
# ['Someone', 'killed', 'Cynthia', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Sarah', 'Crawford', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Alexandra', 'Williams', '.'] [ True]
# ['Someone', 'killed', 'Ian', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Michael', 'Palmer', '.'] [ True]
# ['Someone', 'killed', 'Kenneth', 'Hughes', '.'] [ True]
# ['Someone', 'killed', 'Andrea', 'Carter', '.'] [ True]
# ['Someone', 'killed', 'Jessica', 'King', '.'] [ True]
# ['Someone', 'killed', 'Kate', 'Richardson', '.'] [ True]
# ['Someone', 'killed', 'Kim', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Brian', 'Roberts', '.'] [ True]
# ['Someone', 'killed', 'Ryan', 'White', '.'] [ True]
# ['Someone', 'killed', 'Paul', 'Green', '.'] [ True]
# ['Someone', 'killed', 'Adam', 'Wright', '.'] [ True]
# ['Someone', 'killed', 'Christopher', 'Russell', '.'] [ True]
# ['Someone', 'killed', 'Emma', "O'Brien", '.'] [ True]
# ['Someone', 'killed', 'Virginia', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Lynn', 'Peterson', '.'] [ True]
# ['Someone', 'killed', 'Andrew', 'Rose', '.'] [ True]
# ['Someone', 'killed', 'Patrick', 'Gray', '.'] [ True]
# ['Someone', 'killed', 'Alex', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Ann', 'Wood', '.'] [ True]
# ['Someone', 'killed', 'Donald', 'Harrison', '.'] [ True]
# ['Someone', 'killed', 'Alfred', 'Butler', '.'] [ True]
# ['Someone', 'killed', 'Carol', 'Murray', '.'] [ True]
# ['Someone', 'killed', 'John', 'Davies', '.'] [ True]
# ['Someone', 'killed', 'Frances', 'Morris', '.'] [ True]
# ['Someone', 'killed', 'Peter', 'Turner', '.'] [ True]
# ['Someone', 'killed', 'Bob', 'Campbell', '.'] [ True]
# ['Someone', 'killed', 'Suzanne', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Katie', 'Lewis', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Phillips', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Allen', '.'] [ True]
# ['Someone', 'killed', 'Matt', 'Thomas', '.'] [ True]
# ['Someone', 'killed', 'Jason', 'King', '.'] [ True]
# ['Someone', 'killed', 'Robert', 'Sullivan', '.'] [ True]
# ['Someone', 'killed', 'Annie', 'Foster', '.'] [ True]
# ['Someone', 'killed', 'Tim', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Nancy', 'Smith', '.'] [ True]
# ['Someone', 'killed', 'Leslie', 'Gordon', '.'] [ True]
# ['Someone', 'killed', 'Sharon', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'Marilyn', 'Edwards', '.'] [ True]
# ['Someone', 'killed', 'William', 'Watson', '.'] [ True]
# ['Someone', 'killed', 'Philip', 'Hill', '.'] [ True]
# ['Someone', 'killed', 'Robin', 'Mitchell', '.'] [ True]

# %%
# the following piece of code was adapted from https://howtodoinjava.com/examples/python-print-to-file/
import sys
original_stdout = sys.stdout  
 
with open('Predictions_BiLSTM/false_sentences_without_con.txt', 'a') as f:
    sys.stdout = f 
    print(test.summary(format_example_fn=format_srl), file = f)
    # Reset the standard output
    sys.stdout = original_stdout
