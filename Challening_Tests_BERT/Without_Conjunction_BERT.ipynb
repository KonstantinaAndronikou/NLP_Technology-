# %% [markdown]
# ### Konstantina Andronikou

# %% [markdown]
# ## Comparison with notebook with_conjuction_BERT

# %% [markdown]
# ## This noteboook is implementing a sentence without a conjuction

# %%
from allennlp_models.pretrained import load_predictor

# %%
import checklist
import logging 
import csv
from checklist.editor import Editor
from checklist.perturb import Perturb
from checklist.test_types import MFT, INV, DIR
from checklist.expect import Expect

# %%
from checklist.pred_wrapper import PredictorWrapper

# %%
# To remove all warnings
logging.getLogger('allennlp.common.params').disabled = True 
logging.getLogger('allennlp.nn.initializers').disabled = True 
logging.getLogger('allennlp.modules.token_embedders.embedding').disabled = True 
logging.getLogger('urllib3.connectionpool').disabled = True 
logging.getLogger('allennlp.common.plugins').disabled = True 
logging.getLogger('allennlp.common.model_card').disabled = True 
logging.getLogger('allennlp.models.archival').disabled = True 
logging.getLogger('allennlp.data.vocabulary').disabled = True 
logging.getLogger('cached_path').disabled = True
srl_predictor = load_predictor('structured-prediction-srl-bert')
output = srl_predictor.predict("Someone killed Mary.")
output
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {'verbs': [{'verb': 'killed',
#    'description': '[ARG0: Someone] [V: killed] [ARG1: Mary] .',
#    'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'O']}],
#  'words': ['Someone', 'killed', 'Mary', '.']}

# %%
def predict_srl(data):
    
    pred = []
    for d in data:
        pred.append(srl_predictor.predict(d))
    return pred

predict_and_conf = PredictorWrapper.wrap_predict(predict_srl)

# %%
d = ["Someone killed Mary."]
pred = predict_and_conf(d)
pred
# Out:
# ([{'verbs': [{'verb': 'killed',
#      'description': '[ARG0: Someone] [V: killed] [ARG1: Mary] .',
#      'tags': ['B-ARG0', 'B-V', 'B-ARG1', 'O']}],
#    'words': ['Someone', 'killed', 'Mary', '.']}],
#  array([1.]))

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    
    return pred['verbs'][0]['description']

# %%
def get_arg(pred, arg_target='ARG1'):
    predicate_arguments = pred['verbs'][0]
    #print(predicate_arguments)
    words = pred['words']
    tags = predicate_arguments['tags']
    
    arg_list = []
    for t, w in zip(tags, words):
        arg = t
        if '-' in t:
            arg = t.split('-')[1]
        if arg == arg_target:
            arg_list.append(w)
    arg_set = set(arg_list)
    return arg_set

# %%
def format_srl(x, pred, conf, label=None, meta=None):
    results = []
    predicate_structure = pred['verbs'][0]['description']
        
    return predicate_structure

# %%
def found_arg1_people(x, pred, conf, label=None, meta=None):
    
    # people should be recognized as arg1

    people = set([meta['first_name'],meta['last_name']])
    arg_1 = get_arg(pred, arg_target='ARG1')

    if arg_1 == people:
        pass_ = True
    else:
        pass_ = False
    return pass_


expect_arg1 = Expect.single(found_arg1_people)

# %%
editor = Editor()

# create examples
t = editor.template('Someone killed {first_name} {last_name}.', meta=True, nsamples=1000, remove_duplicates = True)

#print(type(t))

for k, v in t.items():
    print(k, v)
# Out:
# meta [{'last_name': 'Stevens', 'first_name': 'Christopher'}, {'last_name': 'Ford', 'first_name': 'Donna'}, {'last_name': 'Davies', 'first_name': 'Grace'}, {'last_name': 'Reed', 'first_name': 'Karen'}, {'last_name': 'Smith', 'first_name': 'Jerry'}, {'last_name': 'Hall', 'first_name': 'Annie'}, {'last_name': 'Edwards', 'first_name': 'Sandra'}, {'last_name': 'Moore', 'first_name': 'Alice'}, {'last_name': 'King', 'first_name': 'Richard'}, {'last_name': 'Watson', 'first_name': 'Daniel'}, {'last_name': 'Clark', 'first_name': 'Linda'}, {'last_name': 'Stevens', 'first_name': 'Tim'}, {'last_name': 'Stewart', 'first_name': 'Ian'}, {'last_name': 'Scott', 'first_name': 'Billy'}, {'last_name': 'Harris', 'first_name': 'Steven'}, {'last_name': 'Bennett', 'first_name': 'Walter'}, {'last_name': 'Henderson', 'first_name': 'Linda'}, {'last_name': 'Kelly', 'first_name': 'Ed'}, {'last_name': 'Moore', 'first_name': 'Chris'}, {'last_name': 'Harris', 'first_name': 'Carol'}, {'last_name': "O'Brien", 'first_name': 'William'}, {'last_name': 'Edwards', 'first_name': 'Dorothy'}, {'last_name': 'Shaw', 'first_name': 'Catherine'}, {'last_name': 'Bailey', 'first_name': 'Peter'}, {'last_name': 'Hunter', 'first_name': 'Ron'}, {'last_name': 'Brooks', 'first_name': 'Margaret'}, {'last_name': 'Ford', 'first_name': 'Simon'}, {'last_name': 'Robinson', 'first_name': 'James'}, {'last_name': 'White', 'first_name': 'William'}, {'last_name': 'Murphy', 'first_name': 'Dorothy'}, {'last_name': 'Gray', 'first_name': 'Evelyn'}, {'last_name': 'Brown', 'first_name': 'Daniel'}, {'last_name': 'Reynolds', 'first_name': 'Benjamin'}, {'last_name': 'Turner', 'first_name': 'Lynn'}, {'last_name': 'Perry', 'first_name': 'Nicole'}, {'last_name': 'Gray', 'first_name': 'Christine'}, {'last_name': 'Anderson', 'first_name': 'Chris'}, {'last_name': 'Price', 'first_name': 'Nicole'}, {'last_name': 'Jones', 'first_name': 'Alexandra'}, {'last_name': 'Rogers', 'first_name': 'Marie'}, {'last_name': 'Brooks', 'first_name': 'Andrew'}, {'last_name': 'Thompson', 'first_name': 'Betty'}, {'last_name': 'Taylor', 'first_name': 'Claire'}, {'last_name': 'Foster', 'first_name': 'Paul'}, {'last_name': 'Miller', 'first_name': 'Jean'}, {'last_name': 'Kennedy', 'first_name': 'Sue'}, {'last_name': 'Shaw', 'first_name': 'Margaret'}, {'last_name': "O'Brien", 'first_name': 'Sam'}, {'last_name': 'Carter', 'first_name': 'Barbara'}, {'last_name': 'Mason', 'first_name': 'Catherine'}, {'last_name': 'Collins', 'first_name': 'Judy'}, {'last_name': 'Roberts', 'first_name': 'Sharon'}, {'last_name': 'Roberts', 'first_name': 'Kevin'}, {'last_name': 'Thompson', 'first_name': 'Roger'}, {'last_name': 'Butler', 'first_name': 'Jim'}, {'last_name': 'Gordon', 'first_name': 'Amanda'}, {'last_name': 'Price', 'first_name': 'Stephanie'}, {'last_name': 'Parker', 'first_name': 'Katherine'}, {'last_name': 'Rose', 'first_name': 'Sandra'}, {'last_name': 'Martin', 'first_name': 'Tom'}, {'last_name': 'Alexander', 'first_name': 'Marilyn'}, {'last_name': 'Young', 'first_name': 'Matthew'}, {'last_name': 'Smith', 'first_name': 'Thomas'}, {'last_name': 'Johnson', 'first_name': 'Walter'}, {'last_name': 'Crawford', 'first_name': 'Steven'}, {'last_name': 'Turner', 'first_name': 'Bob'}, {'last_name': 'Stevens', 'first_name': 'Linda'}, {'last_name': 'Kelly', 'first_name': 'Jim'}, {'last_name': 'Davies', 'first_name': 'Victoria'}, {'last_name': 'Baker', 'first_name': 'Roy'}, {'last_name': 'Hill', 'first_name': 'Bob'}, {'last_name': 'Watson', 'first_name': 'Walter'}, {'last_name': 'Martin', 'first_name': 'Tim'}, {'last_name': 'Morris', 'first_name': 'William'}, {'last_name': 'Cook', 'first_name': 'Amanda'}, {'last_name': 'Coleman', 'first_name': 'Mike'}, {'last_name': 'Fisher', 'first_name': 'Sara'}, {'last_name': 'Richardson', 'first_name': 'Patricia'}, {'last_name': 'Gordon', 'first_name': 'Jason'}, {'last_name': 'Kelly', 'first_name': 'William'}, {'last_name': 'Adams', 'first_name': 'Virginia'}, {'last_name': 'Murphy', 'first_name': 'Judith'}, {'last_nam ...
# data ['Someone killed Christopher Stevens.', 'Someone killed Donna Ford.', 'Someone killed Grace Davies.', 'Someone killed Karen Reed.', 'Someone killed Jerry Smith.', 'Someone killed Annie Hall.', 'Someone killed Sandra Edwards.', 'Someone killed Alice Moore.', 'Someone killed Richard King.', 'Someone killed Daniel Watson.', 'Someone killed Linda Clark.', 'Someone killed Tim Stevens.', 'Someone killed Ian Stewart.', 'Someone killed Billy Scott.', 'Someone killed Steven Harris.', 'Someone killed Walter Bennett.', 'Someone killed Linda Henderson.', 'Someone killed Ed Kelly.', 'Someone killed Chris Moore.', 'Someone killed Carol Harris.', "Someone killed William O'Brien.", 'Someone killed Dorothy Edwards.', 'Someone killed Catherine Shaw.', 'Someone killed Peter Bailey.', 'Someone killed Ron Hunter.', 'Someone killed Margaret Brooks.', 'Someone killed Simon Ford.', 'Someone killed James Robinson.', 'Someone killed William White.', 'Someone killed Dorothy Murphy.', 'Someone killed Evelyn Gray.', 'Someone killed Daniel Brown.', 'Someone killed Benjamin Reynolds.', 'Someone killed Lynn Turner.', 'Someone killed Nicole Perry.', 'Someone killed Christine Gray.', 'Someone killed Chris Anderson.', 'Someone killed Nicole Price.', 'Someone killed Alexandra Jones.', 'Someone killed Marie Rogers.', 'Someone killed Andrew Brooks.', 'Someone killed Betty Thompson.', 'Someone killed Claire Taylor.', 'Someone killed Paul Foster.', 'Someone killed Jean Miller.', 'Someone killed Sue Kennedy.', 'Someone killed Margaret Shaw.', "Someone killed Sam O'Brien.", 'Someone killed Barbara Carter.', 'Someone killed Catherine Mason.', 'Someone killed Judy Collins.', 'Someone killed Sharon Roberts.', 'Someone killed Kevin Roberts.', 'Someone killed Roger Thompson.', 'Someone killed Jim Butler.', 'Someone killed Amanda Gordon.', 'Someone killed Stephanie Price.', 'Someone killed Katherine Parker.', 'Someone killed Sandra Rose.', 'Someone killed Tom Martin.', 'Someone killed Marilyn Alexander.', 'Someone killed Matthew Young.', 'Someone killed Thomas Smith.', 'Someone killed Walter Johnson.', 'Someone killed Steven Crawford.', 'Someone killed Bob Turner.', 'Someone killed Linda Stevens.', 'Someone killed Jim Kelly.', 'Someone killed Victoria Davies.', 'Someone killed Roy Baker.', 'Someone killed Bob Hill.', 'Someone killed Walter Watson.', 'Someone killed Tim Martin.', 'Someone killed William Morris.', 'Someone killed Amanda Cook.', 'Someone killed Mike Coleman.', 'Someone killed Sara Fisher.', 'Someone killed Patricia Richardson.', 'Someone killed Jason Gordon.', 'Someone killed William Kelly.', 'Someone killed Virginia Adams.', 'Someone killed Judith Murphy.', 'Someone killed Charles Ford.', 'Someone killed Stephen Williams.', 'Someone killed Evelyn Shaw.', 'Someone killed Sophie Hill.', 'Someone killed Walter Wilson.', 'Someone killed Carol Thomas.', 'Someone killed Steven Clarke.', 'Someone killed Bill Stone.', 'Someone killed Roy Sullivan.', 'Someone killed Samuel Stevens.', 'Someone killed Sue Anderson.', 'Someone killed John Mason.', 'Someone killed Anna Rogers.', 'Someone killed Donald Russell.', 'Someone killed Lynn Roberts.', 'Someone killed Simon Coleman.', 'Someone killed Sarah Sullivan.', 'Someone killed Amy Crawford.', 'Someone killed Virginia Russell.', 'Someone killed Howard Nelson.', 'Someone killed Matt Palmer.', 'Someone killed Sam Robertson.', 'Someone killed Kathy Jones.', 'Someone killed Jim Hamilton.', "Someone killed Tony O'Brien.", 'Someone killed Matt Hunter.', 'Someone killed Annie Hart.', 'Someone killed Jessica Stewart.', 'Someone killed Benjamin Foster.', 'Someone killed Larry Allen.', 'Someone killed Heather Gray.', 'Someone killed Richard Morris.', 'Someone killed Deborah Carter.', 'Someone killed Donald Ford.', 'Someone killed Jennifer Stevens.', 'Someone killed Marilyn Henderson.', 'Someone killed Eleanor Gordon.', 'Someone killed Ralph Murray.', 'Someone killed Benjamin Edwards.', 'Someone killed Matthew Jones.', 'Someone ki ...

# %%
# initialize a rest object
test = MFT(**t, name = 'detect_arg0_name_default_position', expect=expect_arg1)
output = test.run(predict_and_conf)
test.summary(format_example_fn=format_srl)
i = test.results['preds']
expect_for_i = test.results['expect_results']
with open ('Output/predictions_without_con_BERT.csv','w') as f:
    writer = csv.writer(f)
    for result, exp in zip(i, expect_for_i):
        
        case = result['words']
        exp = exp
        writer.writerow([case, exp])
        print(case,exp)
# Out:
# Predicting 999 examples

# %%
# the following piece of code was adapted from https://howtodoinjava.com/examples/python-print-to-file/
import sys
original_stdout = sys.stdout  
 
with open('Output/false_sentences_without_con_BERT.txt', 'a') as f:
    sys.stdout = f 
    print(test.summary(format_example_fn=format_srl), file = f)
    # Reset the standard output
    sys.stdout = original_stdout
